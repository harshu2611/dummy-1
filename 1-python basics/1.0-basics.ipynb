# %% [markdown]
# # this is first topic

# %%
1+1
# Out:
# 2

# %%
# !pip install ipykernel

# %%
2+2
# Out:
# 4

# %%
print(1+1)
# Out:
# 2

# %%
# this is good

# %%
## this is good

# %%
"""this is 
just the beginning"""
# Out:
# 'this is \njust the beginning'

# %%
'''this
is
just'''
# Out:
# 'this\nis\njust'

# %%
first_name="harsh"
last_name="kushwaha"

# %%
first_name
# Out:
# 'harsh'

# %%
print(first_name)
# Out:
# harsh

# %%
type(first_name)
# Out:
# str

# %%
age=25
type(age)
# Out:
# int

# %%
weight=5.4
type(weight)
# Out:
# float

# %%
is_check=True
type(is_check)
# Out:
# bool

# %%
weight
# Out:
# 5.4

# %%
# typecasting
int(weight)
# Out:
# 5

# %%
type(str(weight))
# Out:
# str

# %%
int("1")
# Out:
# 1

# %%
int("harsh")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 int("harsh")
#
# ValueError: invalid literal for int() with base 10: 'harsh'

# %%
var=11
print(var,type(var),float(var))
# Out:
# 11 <class 'int'> 11.0

# %%
var="harsh"
print(var,type(var),str(var))
# Out:
# harsh <class 'str'> harsh

# %%
var=3.81
print(var,type(var),int(var))
# Out:
# 3.81 <class 'float'> 3

# %%
# input

val=int(input("please enter any value"))
print(val)
# Out:
# 16

# %%
int("17.8")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 int("17.8")
#
# ValueError: invalid literal for int() with base 10: '17.8'

# %%
int("10")
# Out:
# 10

# %%
# Simple Calculator

num1=float(input("enter first number"))
num2=float(input("enter second number"))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
division = num1 / num2

print(sum, "is the sum")
print(difference, "is the difference")
print(product, "is the product")
print(division, "is the division")
# Out:
# 30.0 is the sum
# 10.0 is the difference
# 200.0 is the product
# 2.0 is the division

# %% [markdown]
# # ABC
# ## ABC
# ### ABC
# #### ABC

# %%
print(1/1)
print(type(1/1))
# Out:
# 1.0
# <class 'float'>

# %%
print(1+1)
print(type(1+1))
# Out:
# 2
# <class 'int'>

# %%
a=20
b=10

# %%
print(type(a+b))
print(type(a-b))
print(type(a*b))
print(type(a/b))
print(type(a**b))
print(type(a//b))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>

# %%
name= "      harsh is my name     "
print(name)
# Out:
#       harsh is my name

# %%
name=name.strip()
print(name)
# Out:
# harsh is my name

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=2
print(a)
# Out:
# 2

# %%
a+=1
print(a)
# Out:
# 3

# %%
a=2
b=3

# %%
print(a<b)
print(a>b)
print(a==b)
print(a>=b)
print(a<=b)
print(a!=b)
# Out:
# True
# False
# False
# False
# True
# True

# %%
a=2
b=3
c=10
d=20

print((a>b) and (c<d))
print((c<d) and (a>b))
print(not(c>d))
# Out:
# False
# False
# True

# %%
name="harsh"

if name =="hars":
    print(name)
else:
    print("no data found")
# Out:
# no data found

# %%
money = int(input("enter your balance"))
time =int(input("enter time(24hrs format):"))

if(money>=200):
    if(time<7):
        print("go to theme park")
    else:
        print("go home")
else:
    if(money<200):
       
        print("go to icecream parlour")
    else:
         print("go to beach")
# Out:
# go to theme park

# %%
names = ["harsh","juhi","ujjwal","vimlesh","alok","kirti",1,2,6,4,9,0.9,0.44]
print(names)
# Out:
# ['harsh', 'juhi', 'ujjwal', 'vimlesh', 'alok', 'kirti', 1, 2, 6, 4, 9, 0.9, 0.44]

# %%
len(names)
# Out:
# 13

# %%
len("juhi")
# Out:
# 4

# %%
a = ["harsh","9555238988","btech","123","cricket","books","cse"]
a[6]
# Out:
# 'cse'

# %%
a[3:6]
# Out:
# ['123', 'cricket', 'books']

# %%
a[::-1]
# Out:
# ['cse', 'books', 'cricket', '123', 'btech', '9555238988', 'harsh']

# %%
a[0:-1]
# Out:
# ['harsh', '9555238988', 'btech', '123', 'cricket', 'books']

# %%
a[:-1]
# Out:
# ['harsh', '9555238988', 'btech', '123', 'cricket', 'books']

# %%
a[1:-4]
# Out:
# ['9555238988', 'btech']

# %%
a[0:-2]
# Out:
# ['harsh', '9555238988', 'btech', '123', 'cricket']

# %%
a[0:len(a)]
# Out:
# ['harsh', '9555238988', 'btech', '123', 'cricket', 'books', 'cse']

# %%
# Out:
# []
