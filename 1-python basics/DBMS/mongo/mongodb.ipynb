# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\python\venv\lib\site-packages (4.13.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\python\venv\lib\site-packages (from pymongo[srv]) (2.7.0)
# WARNING: pymongo 4.13.2 does not provide the extra 'srv'

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
uri = "mongodb+srv://harshkushwaha2611:Harshu@261102@dbharsh.w4ijuqk.mongodb.net/?retryWrites=true&w=majority&appName=dbharsh"

# %%
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Create a new client and connect to the server
# ----> 2 client = MongoClient(uri, server_api=ServerApi('1'))
#       4 # Send a ping to confirm a successful connection
#       5 try:
#
# File c:\python\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:797, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     792 for entity in self._host:
#     793     # A hostname can only include a-z, 0-9, '-' and '.'. If we find a '/'
#     794     # it must be a URI,
#     795     # https://en.wikipedia.org/wiki/Hostname#Restrictions_on_valid_host_names
#     796     if "/" in entity:
# --> 797         res = _validate_uri(
#     798             entity,
#     799             port,
#     800             validate=True,
#     801             warn=True,
#     802             normalize=False,
#     803             srv_max_hosts=srv_max_hosts,
#     804         )
#     805         is_srv = entity.startswith(SRV_SCHEME)
#     806         self._seeds.update(res["nodelist"])
#
# File c:\python\venv\Lib\site-packages\pymongo\uri_parser_shared.py:512, in _validate_uri(uri, default_port, validate, warn, normalize, srv_max_hosts)
#     510 if "@" in host_part:
#     511     userinfo, _, hosts = host_part.rpartition("@")
# --> 512     user, passwd = parse_userinfo(userinfo)
#     513 else:
#     514     hosts = host_part
#
# File c:\python\venv\Lib\site-packages\pymongo\uri_parser_shared.py:85, in parse_userinfo(userinfo)
#      75 """Validates the format of user information in a MongoDB URI.
#      76 Reserved characters that are gen-delimiters (":", "/", "?", "#", "[",
#      77 "]", "@") as per RFC 3986 must be escaped.
#    (...)     82 :param userinfo: A string of the form <username>:<password>
#      83 """
#      84 if "@" in userinfo or userinfo.count(":") > 1 or _unquoted_percent(userinfo):
# ---> 85     raise InvalidURI(
#      86         "Username and password must be escaped according to "
#      87         "RFC 3986, use urllib.parse.quote_plus"
#      88     )
#      90 user, _, passwd = userinfo.partition(":")
#      91 # No password is expected with GSSAPI authentication.
#
# InvalidURI: Username and password must be escaped according to RFC 3986, use urllib.parse.quote_plus
